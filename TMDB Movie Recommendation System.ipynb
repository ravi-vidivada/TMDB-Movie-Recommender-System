# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df1=pd.read_csv(r"C:\Users\rvidivada\tmdb_5000_data\tmdb_5000_credits.csv")
df2=pd.read_csv(r"C:\Users\rvidivada\tmdb_5000_data\tmdb_5000_movies.csv")

# %%
df1.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# ...

# %%
df2.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
df1.columns = ['id','tittle','cast','crew']
df2=df2.merge(df1,on='id')
df2.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
df2.shape
# Out:
# (4803, 23)

# %%
df2.columns
# Out:
# Index(['budget', 'genres', 'homepage', 'id', 'keywords', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'vote_average',
#        'vote_count', 'tittle', 'cast', 'crew'],
#       dtype='object')

# %% [markdown]
# Popularity based recommendations

# %%
#Demographic Filtering using weighted average rating
#mean of vote_average across report

C=df2['vote_average'].mean().round(2)
C
# Out:
# 6.09

# %%
#Minimum votes required to be listed in the chart. we are using 90th percentile as our cutoff.

m=df2['vote_count'].quantile(0.9).round()
m
# Out:
# 1838.0

# %%
#filtering the movies that qualify for the chart. In a nutshell, we are considering the movies who have atleast 1838 votes.

q_movies = df2.copy().loc[df2['vote_count']>=m]
q_movies.shape
# Out:
# (481, 23)

# %% [markdown]
# We see that there are 481 movies which are qualify in this list. so, we have to calculate weighted average for each movie by using weighted rating function
#
#                      Weighted Rating = (v/(v+m) * R) + (m/(m+v) * C)
#                      v = Number of votes
#                      m = Minimum votes required to be listed in the chart
#                      R = Average rating of the movie
#                      C = Mean rating of all movies

# %%
def weighted_rating(x,m=m,C=C):
    v = x['vote_count']
    R = x['vote_average']

    return (v/(v+m) * R) + (m/(m+v) * C)

# %%
#adding a new feature in q_movies as score and calculated its value with 'weighted_rating'
q_movies['score'] = q_movies.apply(weighted_rating, axis=1)

# %%
#sort movies based on score calculates above
q_movies = q_movies.sort_values('score', ascending=False)

#Top 10 movies based on score
q_movies[['title','vote_count','vote_average','score']].head(10)
# Out:
#                                               title  vote_count  vote_average  \
# 1881                       The Shawshank Redemption        8205           8.5
# 662                                      Fight Club        9413           8.3
# 65                                  The Dark Knight       12002           8.2
# 3232                                   Pulp Fiction        8428           8.3
# 96                                        Inception       13752           8.1
# 3337                                  The Godfather        5893           8.4
# 95                                     Interstellar       10867           8.1
# 809                                    Forrest Gump        7927           8.2
# 329   The Lord of the Rings: The Return of the King        8064           8.1
# 1990                        The Empire Strikes Back        5879           8.2
#
#          score
# 1881  8.058939
# 662   7.938967
# 65    7.919785
# 3232  7.904327
# 96    7.863029
# ...

# %%
pop = df2.sort_values('popularity', ascending = False)

plt.figure(figsize=(12,4))
plt.barh(pop['title'].head(5),pop['popularity'].head(5), color='skyblue')
plt.gca().invert_yaxis()
plt.xlabel('Popularity')
plt.title('Popular Movies')
# Out:
# Text(0.5, 1.0, 'Popular Movies')

# %%
df2['score'] = df2.apply(weighted_rating, axis=1)
df2['combined_result'] = 0.7*df2['score'] + 0.3*df2['popularity']
result_df2 = df2[['title','vote_count', 'vote_average', 'popularity','score','combined_result']]
result_df2 = result_df2.sort_values(by='combined_result', ascending=False)
result_df2.head()
# Out:
#                        title  vote_count  vote_average  popularity     score  \
# 546                  Minions        4571           6.4  875.581305  6.311097
# 95              Interstellar       10867           8.1  724.247784  7.809218
# 788                 Deadpool       10995           7.4  514.569956  7.212376
# 94   Guardians of the Galaxy        9742           7.9  481.098624  7.612713
# 127       Mad Max: Fury Road        9427           7.2  434.278564  7.018892
#
#      combined_result
# 546       267.092159
# 95        222.740788
# 788       159.419650
# 94        149.658487
# 127       135.196794

# %% [markdown]
# Content Based Filtering

# %%
df2['overview'].head(5)
# Out:
# 0    In the 22nd century, a paraplegic Marine is di...
# 1    Captain Barbossa, long believed to be dead, ha...
# 2    A cryptic message from Bond’s past sends him o...
# 3    Following the death of District Attorney Harve...
# 4    John Carter is a war-weary, former military ca...
# Name: overview, dtype: object

# %%
#Import TfIdfVectorizer from scikit-learn
from sklearn.feature_extraction.text import TfidfVectorizer

#Define a TF-IDF Vectorizer Object. Remove all english stop words such as 'the', 'a'
tfidf = TfidfVectorizer(stop_words='english')

#Replace NaN with an empty string
df2['overview'] = df2['overview'].fillna('')

#Construct the required TF-IDF matrix by fitting and transforming the data
tfidf_matrix = tfidf.fit_transform(df2['overview'])

tfidf_matrix.shape
# Out:
# (4803, 20978)

# %% [markdown]
# We see that over 20,978 different words were used to describe the 4803 movies in our dataset.

# %%
# Import linear_kernel
from sklearn.metrics.pairwise import linear_kernel

# Compute the cosine similarity matrix
cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)

# %%
#Construct a reverse map of indices and movie titles
indices = pd.Series(df2.index,index = df2['title']).drop_duplicates()
indices.head()
# Out:
# title
# Avatar                                      0
# Pirates of the Caribbean: At World's End    1
# Spectre                                     2
# The Dark Knight Rises                       3
# John Carter                                 4
# dtype: int64

# %%
def get_recommendations(title, cosine_sim = cosine_sim):

    # Get the index of the movie that matches the title
    idx = indices[title]

    #Get the pairwsie similarity scores of all movies with that movie
    sim_scores = list(enumerate(cosine_sim[idx]))

    #sort the movies based on the similarity score
    sim_scores = sorted(sim_scores, key=lambda x:x[1], reverse=True)

    #Select Top 10 Similar Movies
    sim_scores = sim_scores[1:11]

    # Get the movie indices
    movie_indices = [i[0] for i in sim_scores]

    # Return the top 10 most similar movies
    return df2['title'].iloc[movie_indices]

# %%
get_recommendations('The Dark Knight Rises')
# Out:
# 65                              The Dark Knight
# 299                              Batman Forever
# 428                              Batman Returns
# 1359                                     Batman
# 3854    Batman: The Dark Knight Returns, Part 2
# 119                               Batman Begins
# 2507                                  Slow Burn
# 9            Batman v Superman: Dawn of Justice
# 1181                                        JFK
# 210                              Batman & Robin
# Name: title, dtype: object

# %%
get_recommendations('The Avengers')
# Out:
# 7               Avengers: Age of Ultron
# 3144                            Plastic
# 1715                            Timecop
# 4124                 This Thing of Ours
# 3311              Thank You for Smoking
# 3033                      The Corruptor
# 588     Wall Street: Money Never Sleeps
# 2136         Team America: World Police
# 1468                       The Fountain
# 1286                        Snowpiercer
# Name: title, dtype: object
